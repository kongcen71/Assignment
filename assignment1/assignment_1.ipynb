# %%
import pandas as pd
from matplotlib import pyplot as plt

print('So let`s begin the task!')
w_no=input('Please enter the number of the weeks in the month:')
t_no=input('Please enter the number of the tasks:')


list=[]
for i in range(int(t_no)):
    t_name=input('Please the name of No.'+str(i)+' task:')
    task = {'name': t_name}
    for f in range(int(w_no)):
        t_time=input('How many hours did Task '+str(t_name)+' in week'+str(f)+' cost?:')
        task['week'+str(f)]=t_time
    list.append(task)
print(list)

df=pd.DataFrame(list)
print(df)
df.to_csv('WeeklyTasks.csv',mode='w',index=False)

dff = pd.read_csv("WeeklyTasks.csv")



dff=dff.append(dff.mean(),ignore_index=True)
dff.iloc[-1,0]='avg'
print(dff)

x=range(dff.shape[1]-1)

for i in range(dff.shape[0]):
    plt.plot(x,dff.loc[i,'week0':])

plt.legend(dff['name'])
plt.xlabel("Week")
plt.ylabel("hrs")
plt.title('WeeklyTask')
plt.show()
# Out:
# So let`s begin the task!
# Please enter the number of the weeks in the month:4
# Please enter the number of the tasks:4
# Please the name of No.0 task:COM5061
# How many hours did Task COM5061 in week0 cost?:15
# How many hours did Task COM5061 in week1 cost?:4
# How many hours did Task COM5061 in week2 cost?:6
# How many hours did Task COM5061 in week3 cost?:7
# Please the name of No.1 task:COM5950
# How many hours did Task COM5950 in week0 cost?:4
# How many hours did Task COM5950 in week1 cost?:5
# How many hours did Task COM5950 in week2 cost?:4
# How many hours did Task COM5950 in week3 cost?:5
# Please the name of No.2 task:COM5942
# How many hours did Task COM5942 in week0 cost?:3
# How many hours did Task COM5942 in week1 cost?:6
# How many hours did Task COM5942 in week2 cost?:7
# How many hours did Task COM5942 in week3 cost?:8
# Please the name of No.3 task:COM5964
# How many hours did Task COM5964 in week0 cost?:4.5
# How many hours did Task COM5964 in week1 cost?:5
# How many hours did Task COM5964 in week2 cost?:5
# How many hours did Task COM5964 in week3 cost?:6
# [{'name': 'COM5061', 'week0': '15', 'week1': '4', 'week2': '6', 'week3': '7'}, {'name': 'COM5950', 'week0': '4', 'week1': '5', 'week2': '4', 'week3': '5'}, {'name': 'COM5942', 'week0': '3', 'week1': '6', 'week2': '7', 'week3': '8'}, {'name': 'COM5964', 'week0': '4.5', 'week1': '5', 'week2': '5', 'week3': '6'}]
#       name week0 week1 week2 week3
# 0  COM5061    15     4     6     7
# 1  COM5950     4     5     4     5
# 2  COM5942     3     6     7     8
# 3  COM5964   4.5     5     5     6
#       name   week0  week1  week2  week3
# 0  COM5061  15.000    4.0    6.0    7.0
# 1  COM5950   4.000    5.0    4.0    5.0
# 2  COM5942   3.000    6.0    7.0    8.0
# 3  COM5964   4.500    5.0    5.0    6.0
# 4      avg   6.625    5.0    5.5    6.5
