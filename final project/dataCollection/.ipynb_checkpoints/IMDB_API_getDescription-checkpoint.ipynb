# %%
import pandas as pd
import sqlite3
con = sqlite3.connect('../assignment.db')
cursor = con.cursor()

sql = "SELECT n_title,id FROM IMDB;"  # Select all entries from contacts table
try:
    cursor.execute(sql)
    con.commit()
    print("Entry successfully retrieved.")
except Exception as e:
    print("Exception occurred.",e)

result = cursor.fetchall()

#print(type(result))
#print(result)

print('\n')
con.close()
df = pd.DataFrame(result, columns=['title','id'])
df
# Out:
# Entry successfully retrieved.
#                                title         id
# 0                   Star Trek Beyond  tt2660888
# 1            Star Trek Into Darkness  tt1408101
# 2                          Star Trek  tt0796366
# 3            Star Trek: Insurrection  tt0120844
# 4    Star Trek V: The Final Frontier  tt0098382
# ..                               ...        ...
# 140                    Batman Begins  tt0372784
# 141            The Dark Knight Rises  tt1345836
# 142                 The Time Machine  tt0054387
# 143                     Men in Black  tt0119654
# 144                  Men in Black II  tt0120912
#
# [145 rows x 2 columns]

# %%
api_search =" https://imdb-api.com/en/API/Title/"
for i in df['id']:
    if flag%2 == 0:
        r=api_search+"k_tj3n43f9/"+i+'/Images'
    else:
        r=api_search+"k_q67cbnpo/"+i+'/Images'
    print(r)
# Out:
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt2660888/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1408101/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0796366/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0120844/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0098382/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0102975/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0088170/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0084726/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0253754/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0092007/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0117731/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0079945/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0086190/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0080684/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt3748528/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt3778644/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt2488496/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0076759/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1617661/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0183523/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt4682804/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0069293/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt3659388/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt7605074/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1025100/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0021884/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1976009/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0021884/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0109836/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt2798920/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1371111/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0112682/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1375666/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1136608/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0181689/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0343818/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0402158/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0209958/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0139809/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0085271/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0756683/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0470023/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0017136/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0433035/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0258153/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0343818/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt2245084/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0375568/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0910970/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1663662/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1798709/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1823672/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0212720/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0182789/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0470752/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1043842/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0094668/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0468569/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0986263/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt7326248/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt7428594/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1856101/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0083658/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0851578/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1219827/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0113568/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt2209764/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1823672/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0120907/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0093870/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0437086/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0338337/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0268695/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1631867/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0088247/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1409024/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1276104/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0453467/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0289879/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1877832/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt2194499/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0070233/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0070707/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0099088/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0452694/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0096874/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0088763/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0096754/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt6565702/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1477834/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt2316204/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt2231461/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0409459/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt6340500/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt4154796/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1825683/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt4881806/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt4154756/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt4633694/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1877832/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1843866/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt3498820/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt2250912/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt3315342/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt2395427/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt3385516/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1211837/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0451279/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt2617456/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0086393/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0081573/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0078346/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0118929/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt2283362/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt2557478/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt4154916/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt2737304/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1571234/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt2798920/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1677720/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0087544/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0385700/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0299017/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1535108/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1840309/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt2908446/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1951265/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1951266/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt4500922/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt4046784/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1790864/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt4094724/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt6133466/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt2184339/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt2975578/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0114746/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1160419/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt6723592/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0816692/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt2543164/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0372784/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt1345836/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0054387/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0119654/Images
#  https://imdb-api.com/en/API/Title/k_tj3n43f9/tt0120912/Images

# %%
import requests
import time

api_search1 = "https://imdb-api.com/en/API/Ratings/k_tj3n43f9/"
api_search2 = "https://imdb-api.com/en/API/Ratings/k_q67cbnpo/"
api_search =" https://imdb-api.com/en/API/Title/"

plot = []
images= []

i_title=[]
i_id=[]
flag=0
bp=[]
for i in df['id']:
    if flag%2 == 0:
        r=requests.get(api_search+"k_tj3n43f9/"+i+'/Images')
    else:
        r=requests.get(api_search+"k_q67cbnpo/"+i+'/Images')
    
    content = r.json()
    
    print(content['title'])
    
    if df.loc[flag,'title'] == content['title']:
        print('No.',flag,' match')
        print(content['plot'])
        plot.append(content['plot'])
        
        imgL = content['images']['items']
        img = []
        for i in range(4):
            #print (imgL[i]['image'])
            img.append(imgL[i]['image'])
        
        print(img)
        images.append(img)
        
        i_title.append(content['title'])
        i_id.append(content['id'])

        
    else:
        print('No.',flag,' dont`t match, recorded')
        bp.append(flag)
        plot.append('erro')
        images.append('erro')
        
        i_title.append('erro')
        i_id.append('erro')

    flag = flag+1
    time.sleep(1)

print(bp)
# Out:
# Star Trek Beyond
# No. 0  match
# After stopping off at Starbase Yorktown, a remote outpost on the fringes of Federation space, the USS Enterprise, halfway into their five-year mission, is destroyed by an unstoppable wave of unknown aliens. With the crew stranded on an unknown planet and with no apparent means of rescue, they find themselves fighting against a ruthless enemy with a well-earned hatred of the Federation and everything it stands for. Only a rebellious alien warrior can help them reunite and leave the planet to stop this deadly menace from beginning a possible galactic war.
# ['https://imdb-api.com/images/original/MV5BMTU4MTY1NDExNF5BMl5BanBnXkFtZTgwMzE5NzA1MjI@._V1_Ratio1.7800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BODM4MzExNzc4OF5BMl5BanBnXkFtZTgwNTk1NDQ0OTE@._V1_Ratio1.5400_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTUwNTI5OTY4MV5BMl5BanBnXkFtZTgwNjk1NDQ0OTE@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjI0MDEwMzQwNV5BMl5BanBnXkFtZTgwNzk1NDQ0OTE@._V1_Ratio1.5000_AL_.jpg']
# Star Trek Into Darkness
# No. 1  match
# When the USS Enterprise crew is called back home, they find an unstoppable force of terror from within their own organization has detonated the fleet and everything it stands for, leaving our world in a state of crisis. With a personal score to settle, Captain Kirk leads a manhunt to a war-zone world to capture a one-man weapon of mass destruction. As our space heroes are propelled into an epic chess game of life and death, love will be challenged, friendships will be torn apart, and sacrifices must be made for the only family Kirk has left: his crew.
# ['https://imdb-api.com/images/original/MV5BMTgyMTU3OTYwNl5BMl5BanBnXkFtZTcwMjc5NjI1OQ@@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjI0NjMwNTQyNl5BMl5BanBnXkFtZTcwMTAyMDk0OQ@@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTQ3NDcxNzkxMl5BMl5BanBnXkFtZTcwMzAyMDk0OQ@@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BODYyMzI4Mzc2MF5BMl5BanBnXkFtZTcwNDAyMDk0OQ@@._V1_Ratio1.5000_AL_.jpg']
# Star Trek
# No. 2  match
# On the day of James T. Kirk's birth, his father dies on his damaged starship in a last stand against a Romulan mining vessel looking for Ambassador Spock, who in this time, has grown on Vulcan disdained by his neighbors for his half-human heritage. 25 years later, James T. Kirk has grown into a young rebellious troublemaker. Challenged by Captain Christopher Pike to realize his potential in Starfleet, he comes to annoy academy instructors like Commander Spock. Suddenly, there is an emergency on Vulcan and the newly-commissioned USS Enterprise is crewed with promising cadets like Nyota Uhura, Hikaru Sulu, Pavel Chekov and even Kirk himself, thanks to Leonard McCoy's medical trickery. Together, this crew will have an adventure in the final frontier where the old legend is altered forever as a new version of the legend begins.
# ['https://imdb-api.com/images/original/MV5BMjE1NTgxMjM0OV5BMl5BanBnXkFtZTgwNDg1MTE3MzI@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTQ1MDEyNTg4MF5BMl5BanBnXkFtZTcwMzE4NDIzMw@@._V1_Ratio2.4200_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjIyNTkwNjcwOV5BMl5BanBnXkFtZTcwNDE4NDIzMw@@._V1_Ratio2.3800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMzQyNzE2NTgwOF5BMl5BanBnXkFtZTcwNjE4NDIzMw@@._V1_Ratio2.4000_AL_.jpg']
# Star Trek: Insurrection
# No. 3  match
# While on a mission to observe the peaceful Ba'ku race, Lieutenant Commander Data suddenly behaves as if having to fear for his existence. The immortal Ba'ku, whose planet offers regenerative radiation, and therefore incredible lifespans, live in harmony with nature and reject advanced technology. Their planet and their culture is secretly researched by the Federation associated with an alien race called the Son'a. But the Son'a intend to abduct the Ba'ku in order to take the planet for themselves and for the Starfleet officials who all would like to regenerate their bodies. But they did not think of the loyalty of Captain Jean-Luc Picard and the crew of the U.S.S. Enterprise NCC-1701-E to the Prime Directive.
# ['https://imdb-api.com/images/original/MV5BMjM2NjU1NjEwN15BMl5BanBnXkFtZTgwNTE3NDExMjI@._V1_Ratio1.5200_AL_.jpg', 'https://imdb-api.com/images/original/MV5BOTY1NTg4NDk5OV5BMl5BanBnXkFtZTgwMTY1MTAwMjE@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BNzc5Mzg3MDQwOV5BMl5BanBnXkFtZTgwOTU1MTAwMjE@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BNDUwNjQzNzc4M15BMl5BanBnXkFtZTgwMTA5ODY3MTE@._V1_Ratio1.2400_AL_.jpg']
# Star Trek V: The Final Frontier
# No. 4  match
# When the newly-christened starship Enterprise's shakedown cruise goes poorly, Captain Kirk and crew put her into Spacedock for repairs. But an urgent mission interrupts their Earth-bound shore leave. A renegade Vulcan named Sybok has taken three ambassadors hostage on Nimbus III, the Planet of Galactic Peace. This event also attracts the attention of a Klingon captain who wants to make a name for himself and sets out to pursue the Enterprise. Sybok's ragtag army captures the Enterprise and takes her on a journey to the center of the galaxy in search of the Supreme Being.
# ['https://imdb-api.com/images/original/MV5BMTAyODIwNDU1NjFeQTJeQWpwZ15BbWU4MDcxOTM2NzEx._V1_Ratio1.4800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTQ5NzgxNTU4MF5BMl5BanBnXkFtZTgwOTE5MzY3MTE@._V1_Ratio1.4800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjM3NjU2MDE4OF5BMl5BanBnXkFtZTgwODE5MzY3MTE@._V1_Ratio1.4800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTUyMjc2MDE4Ml5BMl5BanBnXkFtZTgwMDI5MzY3MTE@._V1_Ratio1.5000_AL_.jpg']
# Star Trek VI: The Undiscovered Country
# No. 5  match
# After an explosion on their moon, the Klingons have an estimated 50 years before their ozone layer is completely depleted, and they all die. They have only one choice - to make peace with the Federation, which will mean an end to 70 years of conflict. Captain James T. Kirk and crew are called upon to help in the negotiations because of their experience with the Klingons. Peace talks don't quite proceed, and Kirk and McCoy are convicted of assassinating the Klingon High Chancellor, and imprisoned on Rura Penthe, a snowy hard-labor prison camp. Will they manage to escape? And will there ever be peace with the Klingons?
# ['https://imdb-api.com/images/original/MV5BMTg3NDU0NzM1Nl5BMl5BanBnXkFtZTgwMDA3NDMwMjE@._V1_Ratio1.8400_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTUxNzE5NDc1NF5BMl5BanBnXkFtZTgwNDk2NDMwMjE@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjM5ODI1MDAyOV5BMl5BanBnXkFtZTgwNjk2NDMwMjE@._V1_Ratio1.5200_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMzQ4ODA0NDU5MF5BMl5BanBnXkFtZTgwNTk2NDMwMjE@._V1_Ratio1.0000_AL_.jpg']
# Star Trek III: The Search for Spock
# No. 6  match
# In the wake of Spock's ultimate deed of sacrifice, Admiral Kirk and the Enterprise crew return to Earth for some essential repairs to their ship. When they arrive at Spacedock, they are shocked to discover that the Enterprise is to be decommissioned. Even worse, Dr. McCoy begins acting strangely and Scotty has been reassigned to another ship. Kirk is forced to steal back the Enterprise and head across space to the Genesis Planet to save Spock and bring him to Vulcan. Unbeknownst to them, the Klingons are planning to steal the secrets of the Genesis Device for their own deadly purpose.
# ['https://imdb-api.com/images/original/MV5BODkwNDMyMDc0Ml5BMl5BanBnXkFtZTgwOTA4NDExMjI@._V1_Ratio1.4600_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTQwMjQzNzk2NF5BMl5BanBnXkFtZTgwMjY1MTY3MTE@._V1_Ratio1.4600_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTkwMTIyNjQyNF5BMl5BanBnXkFtZTcwNDI2OTk1OQ@@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjAwNDQ0Njk0NF5BMl5BanBnXkFtZTcwNjQwMDA2OQ@@._V1_Ratio1.5000_AL_.jpg']
# Star Trek II: The Wrath of Khan
# No. 7  match
# It is the 23rd century. Admiral James T. Kirk is an instructor at Starfleet Academy and feeling old; the prospect of attending his ship, the USS Enterprise--now a training ship--on a two-week cadet cruise does not make him feel any younger. But the training cruise becomes a deadly serious mission when his nemesis Khan Noonien Singh--infamous conqueror from late 20th century Earth--appears after years of exile. Khan later revealed that the planet Ceti Alpha VI exploded, and shifted the orbit of the fifth planet as a Mars-like haven. He begins capturing Project Genesis, a top secret device holding the power of creation itself, and schemes the utter destruction of Kirk.
# ['https://imdb-api.com/images/original/MV5BMjI2MDQxNzY3Ml5BMl5BanBnXkFtZTgwNjI5NDExMjI@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BNTQxMTYxNTE5Nl5BMl5BanBnXkFtZTgwODI5NDExMjI@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTU5MTY1ODcyMF5BMl5BanBnXkFtZTgwOTI5NDExMjI@._V1_Ratio1.4600_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMzQ2MTcyODkwMF5BMl5BanBnXkFtZTgwMDM5NDExMjI@._V1_Ratio1.4800_AL_.jpg']
# Star Trek: Nemesis
# No. 8  match
# After a joyous wedding between William Riker and Deanna Troi, Captain Picard and the Enterprise crew stumble upon a positronic signature which results in a prototype version of the android Data. Then the Enterprise is invited to Romulus to negotiate a peace treaty with the Romulans by their new leader, Praetor Shinzon. However, Shinzon is revealed to be a clone of Picard who was raised on Remus, a slave planet to the Romulans. Later on, Picard discovers that this peace treaty was nothing more than a set-up on account of the fact that Shinzon needs Picard in order to survive. But little do the Enterprise crew know that Shinzon also plans to do away with the Federation by unleashing a weapon that could destroy a whole planet.
# ['https://imdb-api.com/images/original/MV5BMjExOTE1OTE3OF5BMl5BanBnXkFtZTgwNjMxODc5MDI@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTk3Mzk3MjExN15BMl5BanBnXkFtZTgwNzMxODc5MDI@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTg4MzA3OTQwMF5BMl5BanBnXkFtZTgwNjcwMjAwMjE@._V1_Ratio2.2800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BOTYzNjU3NzgwNl5BMl5BanBnXkFtZTgwNzcwMjAwMjE@._V1_Ratio1.0000_AL_.jpg']
# Star Trek IV: The Voyage Home
# No. 9  match
# The most acclaimed Star Trek adventure of all time with an important message. It is the 23rd century, and a mysterious alien probe is threatening Earth by evaporating the oceans and destroying the atmosphere. In their frantic attempt to save mankind, Admiral Kirk and his crew must time travel back to 1986 San Francisco where they find a world of punk, pizza and exact-change buses that are as alien to them as anything they have ever encountered in the far-off reaches of the galaxy. William Shatner and Leonard Nimoy return as Kirk and Spock, along with the entire Star Trek crew.
# ['https://imdb-api.com/images/original/MV5BNjg4NzQ5MDc5OV5BMl5BanBnXkFtZTgwNTM1ODkwNDM@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTk5MDA0NTE5OF5BMl5BanBnXkFtZTgwNjc3NDExMjI@._V1_Ratio1.7800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTU0NDExNjE3Nl5BMl5BanBnXkFtZTgwMzI5NjM3OTE@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTU0MTY4MDkxMV5BMl5BanBnXkFtZTgwMTIzNjM3OTE@._V1_Ratio1.4800_AL_.jpg']
# Star Trek: First Contact
# No. 10  match
# In the twenty-fourth century, the crew of the U.S.S. Enterprise NCC-1701-E has been ordered to patrol the Romulan Neutral Zone by the Federation to avoid interference with their battle against the insidious Borg. Witnessing the loss of the battle, Captain Jean-Luc Picard ignores orders and takes command of the fleet engaging the Borg. But the Borg plan to travel back into the twenty-first century through a vortex with the intention to stop Earth's first contact with an alien race (the Vulcans). Following the Borg sphere, Picard and his crew realize that they have taken over the Enterprise in order to carry out their mission. Their only chance to do away with the Borg and their seductive Queen is to make sure that Zefram Cochrane makes his famous faster-than-light travel to the stars.
# ['https://imdb-api.com/images/original/MV5BMTY1MzUwMjIxOF5BMl5BanBnXkFtZTgwNzM3NDI4MTI@._V1_Ratio1.3200_AL_.jpg', 'https://imdb-api.com/images/original/MV5BNzEwNTg0NjUzOV5BMl5BanBnXkFtZTcwNTc5MzE0NQ@@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMzgzODAwMjU3MV5BMl5BanBnXkFtZTcwNjc5MzE0NQ@@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTQ5ODE0MDc2Nl5BMl5BanBnXkFtZTYwNjc1MDk2._V1_Ratio1.5000_AL_.jpg']
# Star Trek: The Motion Picture
# No. 11  match
# A massive alien spacecraft of enormous power destroys three powerful Klingon cruisers as it makes its way towards Federation space. Admiral James T. Kirk is ordered to take command of the USS Enterprise for the first time since her historic five-year mission. The Epsilon IX space station alerts the Federation, but they are also destroyed by the alien spacecraft. The only starship in range is the Enterprise, after undergoing a major overhaul in drydock orbiting Earth. Kirk rounds up the rest of his crew, and acquires some new members, and sets off to intercept the alien spacecraft. However, it has been three years since Kirk last went into deep space - is he up to the task of saving Earth?
# ['https://imdb-api.com/images/original/MV5BMjE5NTcyNzUyNV5BMl5BanBnXkFtZTgwODc1NjM3OTE@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTYxMjA4MzgxN15BMl5BanBnXkFtZTgwNTM0NjM3OTE@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTkwMDc3NzcyN15BMl5BanBnXkFtZTgwNDE0NjM3OTE@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTc0Njc1Mzc5NV5BMl5BanBnXkFtZTgwNjYzNjM3OTE@._V1_Ratio1.0000_AL_.jpg']
# Star Wars: Episode VI - Return of the Jedi
# No. 12  match
# Luke Skywalker battles Jabba the Hutt and Darth Vader to save his comrades in the Rebel Alliance and triumph over the Galactic Empire. Han Solo and Princess Leia reaffirm their love, and team with Chewbacca, Lando Calrissian, the Ewoks, and droids C-3PO and R2-D2 to aid in the disruption of the Dark Side, and the defeat of the evil emperor.
# ['https://imdb-api.com/images/original/MV5BNmFlYjhhY2MtODMyYy00ODhlLTliYjktNjgxODM0ODMwYjA1XkEyXkFqcGdeQXVyMTE3OTQ2OTY@._V1_Ratio1.6800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BNDMwMzQ4OTg3M15BMl5BanBnXkFtZTgwMTg3MjQyNDM@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjI4Mjg1Mjk5Ml5BMl5BanBnXkFtZTgwMjg3MjQyNDM@._V1_Ratio1.4600_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTExMTAxODMyMDZeQTJeQWpwZ15BbWU4MDM4NzI0MjQz._V1_Ratio1.4600_AL_.jpg']
# Star Wars: Episode V - The Empire Strikes Back
# No. 13  match
# Luke Skywalker, Han Solo, Princess Leia and Chewbacca face attack by the Imperial forces and its AT-AT walkers on the ice planet Hoth. While Han and Leia escape in the Millennium Falcon, Luke travels to Dagobah in search of Yoda. Only with the Jedi Master's help will Luke survive when the Dark Side of the Force beckons him into the ultimate duel with Darth Vader.
# ['https://imdb-api.com/images/original/MV5BMTU1Mjk0NTEzNV5BMl5BanBnXkFtZTgwNjI4NzUyNDM@._V1_Ratio1.5200_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTYwNTk5OTE1OV5BMl5BanBnXkFtZTgwOTIwMzQyNDM@._V1_Ratio1.3200_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjQzMjEzNjUxOF5BMl5BanBnXkFtZTgwNTEwMzQyNDM@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjAyNDU4NTIwN15BMl5BanBnXkFtZTgwNjEwMzQyNDM@._V1_Ratio1.0000_AL_.jpg']
# Rogue One: A Star Wars Story
# No. 14  match
# All looks lost for the Rebellion against the Empire as they learn of the existence of a new super weapon, the Death Star. Once a possible weakness in its construction is uncovered, the Rebel Alliance must set out on a desperate mission to steal the plans for the Death Star. The future of the entire galaxy now rests upon its success.
# ['https://imdb-api.com/images/original/MV5BMjQxMDQ4ODA4MF5BMl5BanBnXkFtZTgwMTM0NzI5MDI@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTU3MjU5MDA2M15BMl5BanBnXkFtZTgwMDkwNDg4MDI@._V1_Ratio1.7600_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjY4NTQ4MzIwOV5BMl5BanBnXkFtZTgwOTU2MzE3MDI@._V1_Ratio2.4000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BNjEyOTA5NzMzMF5BMl5BanBnXkFtZTgwNTE0NTEzMDI@._V1_Ratio2.3800_AL_.jpg']
# Solo: A Star Wars Story
# No. 15  match
# With the emerging demand of hyperfuel and other resources, Han Solo finds himself in the middle of a heist alongside other criminals, where they meet the likes of Chewbacca and Lando Calrissian in an adventurous situation exposing the criminal underworld.
# ['https://imdb-api.com/images/original/MV5BMjQ2OTYxMTEwN15BMl5BanBnXkFtZTgwMTA0NTE1NTM@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BNTMzMTkwNDUwNl5BMl5BanBnXkFtZTgwMjA0NTE1NTM@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjA3NTM3NDEyMV5BMl5BanBnXkFtZTgwNjgzNTE1NTM@._V1_Ratio1.7800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BNjgyMzk4NjU5MV5BMl5BanBnXkFtZTgwNzgzNTE1NTM@._V1_Ratio1.5000_AL_.jpg']
# Star Wars: Episode VII - The Force Awakens
# No. 16  match
# 30 years after the defeat of Darth Vader and the Empire, Rey, a scavenger from the planet Jakku, finds a BB-8 droid that knows the whereabouts of the long lost Luke Skywalker. Rey, as well as a rogue stormtrooper and two smugglers, are thrown into the middle of a battle between the Resistance and the daunting legions of the First Order.
# ['https://imdb-api.com/images/original/MV5BMTk5NjkzMzAyN15BMl5BanBnXkFtZTgwNDM1ODAyNDM@._V1_Ratio1.7000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjAwNjIyOTk2NV5BMl5BanBnXkFtZTgwODc0ODAyNDM@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjQ0NzMxNjEyNF5BMl5BanBnXkFtZTgwNTE0ODAyNDM@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTgyODc2NDEyNl5BMl5BanBnXkFtZTgwNTAzODAyNDM@._V1_Ratio2.0000_AL_.jpg']
# Star Wars: Episode IV - A New Hope
# No. 17  match
# The Imperial Forces, under orders from cruel Darth Vader, hold Princess Leia hostage in their efforts to quell the rebellion against the Galactic Empire. Luke Skywalker and Han Solo, captain of the Millennium Falcon, work together with the companionable droid duo R2-D2 and C-3PO to rescue the beautiful princess, help the Rebel Alliance and restore freedom and justice to the Galaxy.
# ['https://imdb-api.com/images/original/MV5BMTk3MTkzNTk3Ml5BMl5BanBnXkFtZTgwOTcyMzQyNDM@._V1_Ratio1.3000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjE1NzI5OTAwMl5BMl5BanBnXkFtZTgwMTgyMzQyNDM@._V1_Ratio1.2400_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjQwMjIzNTk3OF5BMl5BanBnXkFtZTgwMjgyMzQyNDM@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjQ3NTM2Nzk2Ml5BMl5BanBnXkFtZTgwNDgyMzQyNDM@._V1_Ratio1.5000_AL_.jpg']
# Jupiter Ascending
# No. 18  match
# Jupiter Jones was born under a night sky, with signs predicting that she was destined for great things. Now grown, Jupiter dreams of the stars but wakes up to the cold reality of a job cleaning other people's houses and an endless run of bad breaks. Only when Caine Wise, a genetically engineered ex-military hunter, arrives on Earth to track her down does Jupiter begin to glimpse the fate that has been waiting for her all along - her genetic signature marks her as next in line for an extraordinary inheritance that could alter the balance of the cosmos.
# ['https://imdb-api.com/images/original/MV5BMTQ4Nzk1Nzk2NF5BMl5BanBnXkFtZTgwNjg3NjUyNDE@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTQ0NzM1Mzc5MF5BMl5BanBnXkFtZTgwNDg3NjUyNDE@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BNjA3MTA4MTYwM15BMl5BanBnXkFtZTgwNTg3NjUyNDE@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTk2MTQ1MTk3MV5BMl5BanBnXkFtZTgwNTAzODQyNDE@._V1_Ratio1.7800_AL_.jpg']
# Mission to Mars
# No. 19  match
# When a mysterious storm kills all but one crew member of the first manned mission to mars, a rescue mission is launched. Once on the red planet, the crew finds the sole survivor of the first mission who informs them that this was no ordinary storm. It was meant to protect something. But what?
# ['https://imdb-api.com/images/original/MV5BNzMzOTg1MjI1N15BMl5BanBnXkFtZTcwMTA2ODYzNQ@@._V1_Ratio2.2400_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTk0MDg3ODAyMV5BMl5BanBnXkFtZTcwMzA2ODYzNQ@@._V1_Ratio1.4800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTY5NDYxODE4N15BMl5BanBnXkFtZTcwNDA2ODYzNQ@@._V1_Ratio2.2400_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTk0OTk5NjQxMF5BMl5BanBnXkFtZTcwNTA2ODYzNQ@@._V1_Ratio2.2400_AL_.jpg']
# Lucy in the Sky
# No. 20  match
# In LUCY IN THE SKY, Natalie Portman plays Lucy Cola, a strong woman whose determination and drive as an astronaut take her to space, where she's deeply moved by the transcendent experience of seeing her life from afar. Back home as Lucy's world suddenly feels too small, her connection with reality slowly unravels.
# ['https://imdb-api.com/images/original/MV5BZWE3OTg2ODgtMWZhYi00MzdmLWFlODEtMmFkYjJkYmFjZDhkXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BZjc1NzJkZTEtMjlhZi00MTFjLWJjNjktYTIxZTk3MDM0NTdhXkEyXkFqcGdeQXVyMTA3MDk2NDg2._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BNmEzMDkxYzItMjdiNC00YzA5LWJmYWMtMzc2Mjc1MTdjNDZiXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BNDg2NWJiZjAtMDhjZC00ZjM3LWE1NzAtZTcxNWNmNGNkZmNiXkEyXkFqcGdeQXVyMzExODEzNDA@._V1_Ratio1.4000_AL_.jpg']
# Solaris
# No. 21  match
# The Solaris mission has established a base on a planet that appears to host some kind of intelligence, but the details are hazy and very secret. After the mysterious demise of one of the three scientists on the base, the main character is sent out to replace him. He finds the station run-down and the two remaining scientists cold and secretive. When he also encounters his wife who has been dead for ten years, he begins to appreciate the baffling nature of the alien intelligence.
# ['https://imdb-api.com/images/original/MV5BMTQ5NjczMDg0N15BMl5BanBnXkFtZTgwMzIyOTIwOTE@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjE3NzgwNDU2Ml5BMl5BanBnXkFtZTgwNDIyOTIwOTE@._V1_Ratio1.0200_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTkzMzg5MzAwM15BMl5BanBnXkFtZTgwNTIyOTIwOTE@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjM2MTExODE5MF5BMl5BanBnXkFtZTgwODQ4MjI2MTE@._V1_Ratio1.2800_AL_.jpg']
# The Martian
# No. 22  match
# During a manned mission to Mars, Astronaut Mark Watney is presumed dead after a fierce storm and left behind by his crew. But Watney has survived and finds himself stranded and alone on the hostile planet. With only meager supplies, he must draw upon his ingenuity, wit and spirit to subsist and find a way to signal to Earth that he is alive. Millions of miles away, NASA and a team of international scientists work tirelessly to bring "the Martian" home, while his crewmates concurrently plot a daring, if not impossible, rescue mission. As these stories of incredible bravery unfold, the world comes together to root for Watney's safe return.
# ['https://imdb-api.com/images/original/MV5BMTc1NzE5NDc5MV5BMl5BanBnXkFtZTgwNjUxNjg1NjE@._V1_Ratio1.3200_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjA3NzY4MzcwNl5BMl5BanBnXkFtZTgwNTUxNjg1NjE@._V1_Ratio1.6200_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMzA2MDIxMjE0N15BMl5BanBnXkFtZTgwNjg4MDM5NTE@._V1_Ratio1.4400_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTc1NTU4Nzg0MF5BMl5BanBnXkFtZTgwNzg4MDM5NTE@._V1_Ratio1.5000_AL_.jpg']
# The Wandering Earth
# No. 23  match
# The sun is dying out. The earth will soon be engulfed by the inflating sun. To save the human civilization, scientists draw up an escape plan that will bring the whole human race from danger. With the help of thousands of infusion powered engines, the planet earth will leave the solar system and embark on a 2,500 year journey to the orbit of a star 4.5 light years away.
# ['https://imdb-api.com/images/original/MV5BZDIwMTdhZDEtMGIxMi00NGNlLWFkZDctOWZhMDFjM2E5MDE0XkEyXkFqcGdeQXVyMTA4NjE0NjEy._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BNTcxMDFhZWUtNmFhYS00MWU1LWFiY2EtYmUzOTE2NGMzYzAzXkEyXkFqcGdeQXVyMTA4NjE0NjEy._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BODI4OGFkOWEtYzE5My00YmFkLWFlM2UtNjcxNzQ5ZGZjY2Q1XkEyXkFqcGdeQXVyMTk2MDc1MjQ@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BYTdkYzQwZmMtNDcwZC00NDBkLWJhMDQtYmJiOTdiYjkzZDk0XkEyXkFqcGdeQXVyMTExNDQ2MTI@._V1_Ratio1.4600_AL_.jpg']
# Gemini Man
# No. 24  match
# A retiring assassin, Henry Brogan, finds himself pursued by a mysterious killer that can predict his every move. Discovering that he's being hunted by a younger clone of himself, Henry needs to find out why he's being targeted and who the creator is.
# ['https://imdb-api.com/images/original/MV5BMGYyNmMzZWUtZDlmYy00ODA5LWI3Y2QtZGEzYzkwYjEwMDU3XkEyXkFqcGdeQXVyODk4OTc3MTY@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMDNkYmZmOTgtMWU4Ny00ZDIzLTlmNjktNzMxZmVhMmRhNTRmXkEyXkFqcGdeQXVyODk4OTc3MTY@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BOGI2ZDE5MjgtOTkyNy00MjcyLWE4NmUtZGQ0MzFjNTE5YTAzXkEyXkFqcGdeQXVyODk4OTc3MTY@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTc1NTZmOWEtNDlkMS00OThhLTlmMTQtOWNlODUzOTZmNGM1XkEyXkFqcGdeQXVyODk4OTc3MTY@._V1_Ratio1.5000_AL_.jpg']
# Frankenstein
# No. 25  match
# Henry Frankenstein is a doctor who is trying to discover a way to make the dead walk. He succeeds and creates a monster that has to deal with living again.
# ['https://imdb-api.com/images/original/MV5BMTAxOTMxMDg4MzReQTJeQWpwZ15BbWU4MDYxNTE1MTUz._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTkyNzEzMTMyMF5BMl5BanBnXkFtZTgwNDg2Njc5MTE@._V1_Ratio1.2800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjIxNjQzMTUwNF5BMl5BanBnXkFtZTgwNTg2Njc5MTE@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTc0OTIxNzY0MV5BMl5BanBnXkFtZTgwNjg2Njc5MTE@._V1_Ratio1.0000_AL_.jpg']
# Victor Frankenstein
# No. 26  match
# James McAvoy and Daniel Radcliffe star in a dynamic and thrilling twist on a legendary tale. Radical scientist Victor Frankenstein (McAvoy) and his equally brilliant protégé Igor Strausman (Radcliffe) share a noble vision of aiding humanity through their groundbreaking research into immortality. But Victor's experiments go too far, and his obsession has horrifying consequences. Only Igor can bring his friend back from the brink of madness and save him from his monstrous creation.
# ['https://imdb-api.com/images/original/MV5BMjA3NTMwMDQ2OV5BMl5BanBnXkFtZTgwNDYwNjA0NzE@._V1_Ratio1.3400_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjIwMDkzMzE2NF5BMl5BanBnXkFtZTgwMTUwNjA0NzE@._V1_Ratio1.3800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTc5MjEzMTI0NF5BMl5BanBnXkFtZTgwNTUwNjA0NzE@._V1_Ratio1.3800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTc4OTYwODI4Nl5BMl5BanBnXkFtZTgwMzUwNjA0NzE@._V1_Ratio1.3800_AL_.jpg']
# Frankenstein
# No. 27  match
# Henry Frankenstein is a doctor who is trying to discover a way to make the dead walk. He succeeds and creates a monster that has to deal with living again.
# ['https://imdb-api.com/images/original/MV5BMTAxOTMxMDg4MzReQTJeQWpwZ15BbWU4MDYxNTE1MTUz._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTkyNzEzMTMyMF5BMl5BanBnXkFtZTgwNDg2Njc5MTE@._V1_Ratio1.2800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjIxNjQzMTUwNF5BMl5BanBnXkFtZTgwNTg2Njc5MTE@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTc0OTIxNzY0MV5BMl5BanBnXkFtZTgwNjg2Njc5MTE@._V1_Ratio1.0000_AL_.jpg']
# Mary Shelley's Frankenstein
# No. 28  match
# In 1794, in the Arctic Sea, Captain Robert Walton is a man obsessed to reach the North Pole, pushing his crew to exhaustion. When his ship hits an iceberg, it is stranded in the ice. Out of the blue, Captain Walton and his men overhear a dreadful cry and they see a stranger coming to the ship. He introduces himself as Victor Frankenstein and he tells the Captain the story of his life since he was a little boy in Geneva. Victor is a barilliant student, and in love with his stepsister Elizabeth, an orphan that was raised by his father Baron Victor von Frankenstein. In 1793, Victor moves to Ingolstadt to study at the university, and he promises to get married to Elizabeth. At the university, Victor befriends Henry Clerval, who becomes his best friend. Victor gets close to Professor Waldman and decides to create life to cheat death, but Waldman advises him that he should not try this experiment, since the result would be an abomination. When Waldman dies, Victor steals his notes and tries to create life. He succeeds and gives life to a strong Creature, composed of parts of deceased people. However, he realizes that his experiment is a mistake and he abandons the Creature, expecting that it will die alone. However the Creature survives and learns how to read and write, but he is a monster rejected by society and his own creator. The Creature decides to seek revenge from Victor by killing everyone he loves.
# ['https://imdb-api.com/images/original/MV5BMjA1NTc5MDExMV5BMl5BanBnXkFtZTcwMDMxNTkyNA@@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjI0Nzk2MDUyNV5BMl5BanBnXkFtZTcwMTMxNTkyNA@@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BODA4ODk2MDk2OF5BMl5BanBnXkFtZTcwMzMxNTkyNA@@._V1_Ratio1.2800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTQ0NjY0NTQ3MV5BMl5BanBnXkFtZTcwNzY2NTgwMw@@._V1_Ratio1.0000_AL_.jpg']
# Annihilation
# No. 29  match
# A biologist's husband disappears. She puts her name forward for an expedition into an environmental disaster zone, but does not find what she's expecting. The expedition team is made up of the biologist, an anthropologist, a psychologist, a surveyor, and a linguist.
# ['https://imdb-api.com/images/original/MV5BNzk0NTA1NzkwM15BMl5BanBnXkFtZTgwNDcwOTc3NDM@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjI2Mzk1MjA2NV5BMl5BanBnXkFtZTgwNjcwOTc3NDM@._V1_Ratio1.3800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTA0NzUyNDA0OTleQTJeQWpwZ15BbWU4MDg3MDk3NzQz._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjM3OTE4NjU4Nl5BMl5BanBnXkFtZTgwOTcwOTc3NDM@._V1_Ratio1.5000_AL_.jpg']
# Cloud Atlas
# No. 30  match
# Everything is connected: an 1849 diary of an ocean voyage across the Pacific, letters from a composer to his lover, a thriller about a conspiracy at a nuclear power plant, a farce about a publisher in a nursing home;, a rebellious clone in futuristic Korea, and the tale of a tribe living on post-apocalyptic Hawaii far in the future.
# ['https://imdb-api.com/images/original/MV5BMTg1NjQ5OTIwNV5BMl5BanBnXkFtZTcwNDY3MTA2OA@@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTg4NjQ5NzUwN15BMl5BanBnXkFtZTcwNjY3MTA2OA@@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTY3MDUyMDYxOF5BMl5BanBnXkFtZTcwNzY3MTA2OA@@._V1_Ratio1.6200_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTM1OTI4ODgxMV5BMl5BanBnXkFtZTcwODY3MTA2OA@@._V1_Ratio2.4000_AL_.jpg']
# The City of Lost Children
# No. 31  match
# Set in a dystopian society, someone is kidnapping the children. Krank and his band of clones are using the children to harvest their dreams. Then they kidnap Denree, the brother of One, a fairground strongman. One sets out to find his brother.
# ['https://imdb-api.com/images/original/MV5BMmJlMjBhN2MtMTRlZC00MTI3LWEzM2EtNDU2MjY2ZGY5OTQ4XkEyXkFqcGdeQXVyODIyOTEyMzY@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BZGM4MjU0ZTEtMjBmMS00OTFiLWEyZWUtNjhkOTJkMGQ5OWFkXkEyXkFqcGdeQXVyODc0OTEyNDU@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTg1OTk5OTM5Nl5BMl5BanBnXkFtZTcwNjM5MzI4OA@@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTg2MDkyMDkzOF5BMl5BanBnXkFtZTcwNDM3Njk4Ng@@._V1_Ratio1.0000_AL_.jpg']
# Inception
# No. 32  match
# Dom Cobb is a skilled thief, the absolute best in the dangerous art of extraction, stealing valuable secrets from deep within the subconscious during the dream state, when the mind is at its most vulnerable. Cobb&#39;s rare ability has made him a coveted player in this treacherous new world of corporate espionage, but it has also made him an international fugitive and cost him everything he has ever loved. Now Cobb is being offered a chance at redemption. One last job could give him his life back but only if he can accomplish the impossible, inception. Instead of the perfect heist, Cobb and his team of specialists have to pull off the reverse: their task is not to steal an idea, but to plant one. If they succeed, it could be the perfect crime. But no amount of careful planning or expertise can prepare the team for the dangerous enemy that seems to predict their every move. An enemy that only Cobb could have seen coming.
# ['https://imdb-api.com/images/original/MV5BMjIyNjk1OTgzNV5BMl5BanBnXkFtZTcwOTU0OTk1Mw@@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BNjMxNjI1Mjc1OV5BMl5BanBnXkFtZTcwMDY0OTk1Mw@@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTk1NDM4MDMwMF5BMl5BanBnXkFtZTcwMjY0OTk1Mw@@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTY3MzMzMDgyMF5BMl5BanBnXkFtZTcwMzY0OTk1Mw@@._V1_Ratio1.5000_AL_.jpg']
# District 9
# No. 33  match
# In 1982, a massive star ship bearing a bedraggled alien population, nicknamed "The Prawns," appeared over Johannesburg, South Africa. Twenty-eight years later, the initial welcome by the human population has faded. The refugee camp where the aliens were located has deteriorated into a militarized ghetto called District 9, where they are confined and exploited in squalor. In 2010, the munitions corporation, Multi-National United, is contracted to forcibly evict the population with operative Wikus van der Merwe in charge. In this operation, Wikus is exposed to a strange alien chemical and must rely on the help of his only two new 'Prawn' friends.
# ['https://imdb-api.com/images/original/MV5BMTk1MzUxMzM5Ml5BMl5BanBnXkFtZTcwNjE3MzQ3Mg@@._V1_Ratio1.7800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTkwODQ4ODI5OF5BMl5BanBnXkFtZTcwNzE3MzQ3Mg@@._V1_Ratio1.7800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjAwOTM4MDIxMF5BMl5BanBnXkFtZTcwODE3MzQ3Mg@@._V1_Ratio1.7800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTI1ODk5NjQ0OF5BMl5BanBnXkFtZTcwOTE3MzQ3Mg@@._V1_Ratio1.7800_AL_.jpg']
# Minority Report
# No. 34  match
# In the year 2054 A.D. crime is virtually eliminated from Washington D.C. thanks to an elite law enforcing squad "Precrime". They use three gifted humans (called "Pre-Cogs") with special powers to see into the future and predict crimes beforehand. John Anderton heads Precrime and believes the system's flawlessness steadfastly. However one day the Pre-Cogs predict that Anderton will commit a murder himself in the next 36 hours. Worse, Anderton doesn't even know the victim. He decides to get to the mystery's core by finding out the 'minority report' which means the prediction of the female Pre-Cog Agatha that "might" tell a different story and prove Anderton innocent.
# ['https://imdb-api.com/images/original/MV5BMTkwNjM2MzI3N15BMl5BanBnXkFtZTcwNzIyOTAzMw@@._V1_Ratio1.6600_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTg0MDA4MjE3NF5BMl5BanBnXkFtZTcwODIyOTAzMw@@._V1_Ratio1.6200_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjE3NzgyMzY0N15BMl5BanBnXkFtZTcwOTIyOTAzMw@@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTY3MTAwNDk5NF5BMl5BanBnXkFtZTcwMDMyOTAzMw@@._V1_Ratio1.0000_AL_.jpg']
# I, Robot
# No. 35  match
# In 2035, techno-phobic homicide detective Del Spooner of the Chicago PD heads the investigation of the apparent suicide of leading robotics scientist, Dr. Alfred Lanning. Unconvinced of the motive, Spooner's investigation into Lanning's death reveals a trail of secrets and agendas within the USR (United States Robotics) corporation and suspicions of murder. Little does he know that his investigation would lead to uncovering a larger threat to humanity.
# ['https://imdb-api.com/images/original/MV5BMjM4Mjc2MzU3MF5BMl5BanBnXkFtZTgwNjYwMDIwMjE@._V1_Ratio1.8000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTk1MTY4ODcyNF5BMl5BanBnXkFtZTgwNTYwMDIwMjE@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjMxNTUyNTAyOV5BMl5BanBnXkFtZTgwNzYwMDIwMjE@._V1_Ratio1.7800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTQ2MzUxMDQ2N15BMl5BanBnXkFtZTgwODYwMDIwMjE@._V1_Ratio1.7600_AL_.jpg']
# Empire of the Wolves
# No. 36  match
# Suffering from terrifying hallucinations and alarmingly frequent incidents of amnesia, Anna Heymes, the troubled wife of a French civil servant, finds it increasingly difficult to remember the face of her husband. In the meantime, as the third mutilated body of a Turkish woman emerges from the dark Parisian sewers, the young chief of the investigation, Paul Nerteaux, enlists the help of the dishonoured former detective, Jean-Louis Schiffer. Now, Schiffer's brutal methods, along with his profound experience, are Paul's last hope to shed light on this intricate case. Can they find who is behind the gruesome murders before it's too late?
# ['https://imdb-api.com/images/original/MV5BMTYwNDM1MTY4MF5BMl5BanBnXkFtZTgwNzYyOTkwMzE@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjA4MzMyNjEyNV5BMl5BanBnXkFtZTcwMjExNTgzMg@@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTI4MDkxMjc3M15BMl5BanBnXkFtZTcwMzExNTgzMg@@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTI0MTk1NDg0NF5BMl5BanBnXkFtZTcwOTAxNTgzMg@@._V1_Ratio1.0000_AL_.jpg']
# The Cell
# No. 37  match
# Catharine Deane is a psychotherapist who is part of a revolutionary new treatment which allows her mind to literally enter the mind of her patients. Her experience in this method takes an unexpected turn when an F.B.I. Agent comes to ask for a desperate favor. They had just tracked down a notorious serial killer, Carl Stargher, whose method of operation is to abduct women one at a time and place them in a secret area where they are kept for about forty hours until they are slowly drowned. Unfortunately, the killer has fallen into an irreversible coma which means he cannot confess where he has taken his latest victim before she dies. Now, Catherine Deane must race against time to explore the twisted mind of the killer to get the information she needs, but Stargher's damaged personality poses dangers that threaten to overwhelm her.
# ['https://imdb-api.com/images/original/MV5BMjE5NTA5MzgwN15BMl5BanBnXkFtZTcwMDA1MDQ1NA@@._V1_Ratio1.4800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTY4Mjg2ODk1OF5BMl5BanBnXkFtZTcwMTA1MDQ1NA@@._V1_Ratio1.4800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjIwNTAwNjM2NV5BMl5BanBnXkFtZTcwMjA1MDQ1NA@@._V1_Ratio1.4800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTgxNzEzODE4N15BMl5BanBnXkFtZTcwMzA1MDQ1NA@@._V1_Ratio1.5000_AL_.jpg']
# The Thirteenth Floor
# No. 38  match
# Computer scientist Hannon Fuller has discovered something extremely important. He's about to tell the discovery to his colleague, Douglas Hall, but knowing someone is after him, the old man leaves a letter in the computer generated parallel world his company has created (which looks like the 30's with seemingly real people with real emotions). Fuller is murdered in our real world the same night, and his colleague is suspected. Douglas discovers a bloody shirt in his bathroom and he cannot recall what he was doing the night Fuller was murdered. He logs into the system in order to find the letter, but has to confront the unexpected. The truth is harsher than he could ever imagine...
# ['https://imdb-api.com/images/original/MV5BMTYxOTA1MjkwMF5BMl5BanBnXkFtZTYwNDQ5ODM3._V1_Ratio1.4800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTU2ODYzMjcyOF5BMl5BanBnXkFtZTYwODQ5ODM3._V1_Ratio1.4800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjE5MDQxOTY3Nl5BMl5BanBnXkFtZTYwMTU5ODM3._V1_Ratio1.4800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTY5MzYwNTMyN15BMl5BanBnXkFtZTYwMzU5ODM3._V1_Ratio1.4600_AL_.jpg']
# Brainstorm
# No. 39  match
# Brilliant researchers Lillian Reynolds and Michael Brace have developed a system of recording and playing back actual experiences of people. Once the capability of tapping into "higher brain functions" is added in, and you can literally jump into someone else's head and play back recordings of what he or she was thinking, feeling, seeing, etc., at the time of the recording, the applications for the project quickly spiral out of control. While Michael Brace uses the system to become close again to Karen Brace, his estranged wife who also works on the project, others start abusing it for intense sexual experiences and other logical but morally questionable purposes. The government tries to kick Michael and Lillian off the project once the vast military potential of the technology is discovered. It soon becomes obvious that the government is interested in more than just missile guidance systems. The lab starts producing mind torture recordings and other psychosis inducing material. When ...
# ['https://imdb-api.com/images/original/MV5BMTg0MDc1MzIwN15BMl5BanBnXkFtZTYwNzcxNzQ2._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTg0MTYxNjI3NF5BMl5BanBnXkFtZTYwNTcxNzQ2._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjE0ODcwNzA0NV5BMl5BanBnXkFtZTcwMTYxNTYyMg@@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjA1NTU0NTI5M15BMl5BanBnXkFtZTYwNTQyMTk4._V1_Ratio1.0000_AL_.jpg']
# The Man from Earth
# No. 40  match
# An impromptu goodbye party for Professor John Oldman becomes a mysterious interrogation after the retiring scholar reveals to his colleagues he has a longer and stranger past than they can imagine.
# ['https://imdb-api.com/images/original/MV5BMTY3NzMyOTgxMV5BMl5BanBnXkFtZTcwMTI1NTg0Nw@@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTQyMDI0MDM5MF5BMl5BanBnXkFtZTcwMjI1NTg0Nw@@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BNzgzMjMyMTYwOV5BMl5BanBnXkFtZTcwMzI1NTg0Nw@@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTM4MTUzNzU4Ml5BMl5BanBnXkFtZTcwNDI1NTg0Nw@@._V1_Ratio1.5000_AL_.jpg']
# Android Apocalypse
# No. 41  match
# In an age when Machines dominate the world, the fate of man rests in the hands of an outlaw and an android.
# ['https://imdb-api.com/images/original/MV5BMTQ1NTQ4MDEwMl5BMl5BanBnXkFtZTgwMzQ0MDAxMzE@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BNTEzMzMzNDM4Nl5BMl5BanBnXkFtZTcwNjk5NzQ0MQ@@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BZDdmYzJiZDEtMmRmYi00OTdhLWE1NTUtNTU4MjRmYTI5YzhhXkEyXkFqcGdeQXVyNDQ4NjQxNA@@._V1_Ratio1.6200_AL_.jpg', 'https://imdb-api.com/images/original/MV5BNjNiYjg3MzMtZTE2YS00Nzk5LTk2YzItYjdhMTRhYTc1NGI3XkEyXkFqcGdeQXVyNDQ4NjQxNA@@._V1_Ratio1.6800_AL_.jpg']
# Metropolis
# No. 42  match
# Sometime in the future, the city of Metropolis is home to a Utopian society where its wealthy residents live a carefree life. One of those is Freder Fredersen. One day, he spots a beautiful woman with a group of children, she and the children quickly disappear. Trying to follow her, he is horrified to find an underground world of workers who apparently run the machinery that keeps the Utopian world above ground functioning. One of the few people above ground who knows about the world below is Freder's father, John Fredersen, who is the founder and master of Metropolis. Freder learns that the woman is called Maria, who espouses the need to join the "hands" - the workers - to the "head" - those in power above - by a mediator who will act as the "heart". Freder wants to help the plight of the workers in their struggle for a better life. But when John learns of what Maria is advocating and that Freder has joined their cause, with the assistance of an old colleague. an inventor called ...
# ['https://imdb-api.com/images/original/MV5BMjg4NTEwNDAzMF5BMl5BanBnXkFtZTgwOTczMjYzMzE@._V1_Ratio1.3200_AL_.jpg', 'https://imdb-api.com/images/original/MV5BNjQxNTgyNTU5Nl5BMl5BanBnXkFtZTgwMTczMjYzMzE@._V1_Ratio1.3800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BODUwNTM5MTAwMl5BMl5BanBnXkFtZTgwMjYzMjYzMzE@._V1_Ratio1.3600_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTU2ODA5MTk1NF5BMl5BanBnXkFtZTgwOTAzMjYzMzE@._V1_Ratio1.3400_AL_.jpg']
# Real Steel
# No. 43  match
# In the near future when people become uninterested in boxing and similar sports, a new sport is created - Robot boxing wherein robots battle each other while being controlled by someone. Charlie Kenton, a former boxer who's trying to make it in the new sport, not only doesn't do well, he is very deeply in the red. When he learns that his ex, mother of his son Max, dies, he goes to figure out what to do with him. His ex's sister wants to take him in but Charlie has first say in the matter. Charlie asks her husband for money so he can buy a new Robot in exchange for turning Max over to them. He takes Max for the summer. And Max improves his control of his robot. But when the robot is destroyed, they go to a scrap yard to get parts. Max finds an old generation robot named Atom and restores him. Max wants Atom to fight but Charlie tells him he won't last a round. However, Atom wins. And it isn't long before Atom is getting major bouts. Max gets Charlie to teach Atom how to fight, and the ...
# ['https://imdb-api.com/images/original/MV5BMTQzNTAxNjE0NF5BMl5BanBnXkFtZTcwMTcyNTIyNQ@@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjAxMDIyOTk1OF5BMl5BanBnXkFtZTcwMzcyNTIyNQ@@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTM3NjY0MDM3Ml5BMl5BanBnXkFtZTcwNDcyNTIyNQ@@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTYzMTY3NDQ3Nl5BMl5BanBnXkFtZTcwNTcyNTIyNQ@@._V1_Ratio1.7800_AL_.jpg']
# S1m0ne
# No. 44  match
# The career of a disillusioned producer, who is desperate for a hit, is endangered when his star walks off the film set. Forced to think fast, the producer decides to digitally create an actress "Simone" to sub for the star--the first totally believable synthetic actress. The "actress" becomes an overnight sensation, with a major singing career as well, and everyone thinks she's a real person. However, as Simone's fame skyrockets, he cannot bear to admit his fraud to himself or the world.
# ['https://imdb-api.com/images/original/MV5BNzY4OTgzMTQzNl5BMl5BanBnXkFtZTcwNTM0NzU0NA@@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTk5MTAzOTQyNV5BMl5BanBnXkFtZTcwNjM0NzU0NA@@._V1_Ratio1.5400_AL_.jpg', 'https://imdb-api.com/images/original/MV5BNjY5OTUzMTkwMV5BMl5BanBnXkFtZTcwNzM0NzU0NA@@._V1_Ratio1.4800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTg1ODQ3MTMyN15BMl5BanBnXkFtZTcwOTM0NzU0NA@@._V1_Ratio1.4800_AL_.jpg']
# I, Robot
# No. 45  match
# In 2035, techno-phobic homicide detective Del Spooner of the Chicago PD heads the investigation of the apparent suicide of leading robotics scientist, Dr. Alfred Lanning. Unconvinced of the motive, Spooner's investigation into Lanning's death reveals a trail of secrets and agendas within the USR (United States Robotics) corporation and suspicions of murder. Little does he know that his investigation would lead to uncovering a larger threat to humanity.
# ...
# Aquaman
# No. 89  match
# Born upon the shores of the surface world, Arthur Curry (Jason Momoa) discovers that he is only half human, with the other half of his blood being of Atlanteean descent, thus making him the rightful heir to the throne of the undersea kingdom of Atlantis. However, Arthur learns that Atlantis is being ruled by his malicious half-brother Orm (Patrick Wilson), who seeks to unite the seven underwater kingdoms and wage war upon the surface. With aid from Nuidis Vulko (Willem Dafoe) and the gorgeous Mera (Amber Heard), Arthur must discover the full potential of his true destiny and become Aquaman in order to save Atlantis and the surface from Orm's evil plot.
# ['https://imdb-api.com/images/original/MV5BMjE2MDg1OTg5NF5BMl5BanBnXkFtZTgwMTIwMTg0NjM@._V1_Ratio1.7800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjQ2MDczNzEzMV5BMl5BanBnXkFtZTgwOTE2MTgwNjM@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjE3Nzk1NDMzMV5BMl5BanBnXkFtZTgwMjI2MTgwNjM@._V1_Ratio2.4000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTU2ODM3MTk2Ml5BMl5BanBnXkFtZTgwMzI2MTgwNjM@._V1_Ratio2.3800_AL_.jpg']
# Alien: Covenant
# No. 90  match
# In 2104, almost eleven years after the disastrous expedition to the distant moon, LV-223, in Prometheus (2012), the deep-space colonisation vessel, USCSS Covenant, is on course for the remote planet, Origae-6, with more than 2,000 colonists in cryogenic hibernation to build a new world. Instead, a rogue transmission entices the crew to a nearby habitable planet which resembles Earth. As a result, the unsuspecting crewmembers of the Covenant will have to cope with biological foes beyond human comprehension. Now, what started as a peaceful exploratory mission, will soon turn into a desperate rescue operation in uncharted space. Is there an escape from the treacherous, mysterious planet?
# ['https://imdb-api.com/images/original/MV5BODZjMGUxYmItMGQzOC00MzBhLThiYjAtYzIwNmNhZWUyNDM0XkEyXkFqcGdeQXVyNDg2MjUxNjM@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BYzgzYWFlMmQtMjJkOS00YTNiLTliNmEtODEwMjUxNDdmY2E5XkEyXkFqcGdeQXVyNDg2MjUxNjM@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BOGY1NzYxY2ItMWEwNy00NDE2LTk5NTEtOTkyMDBkN2ZiMzkwXkEyXkFqcGdeQXVyNDg2MjUxNjM@._V1_Ratio1.4400_AL_.jpg', 'https://imdb-api.com/images/original/MV5BN2Q1ODUyYzItNDNlOC00YzM3LWE4MjItZGZkYTU5N2MxNWFiXkEyXkFqcGdeQXVyNDg2MjUxNjM@._V1_Ratio1.5000_AL_.jpg']
# Rampage
# No. 91  match
# Athena-1, a space station owned by gene manipulation company Energyne, is destroyed after a laboratory rat mutates and wreaks havoc. Dr. Kerry Atkins, the lone surviving crew member, is ordered by CEO Claire Wyden to retrieve research canisters containing a pathogen. Atkins is able to flee in the escape pod when the station implodes, but due to damage from the rat it disintegrates upon re-entry, killing her. The falling pieces leave a trail of debris across the United States, including the Everglades in Florida, where a canister is consumed by an American crocodile, and a forest in Wyoming, where a gray wolf is exposed to the pathogen. Primatologist Davis Okoye, a former US Army Special Forces soldier and member of an anti-poaching unit, works at the San Diego Wildlife Sanctuary. He has befriended a rare albino western lowland gorilla named George, having saved him from poachers, and communicates with George using sign language and hand gestures. At night, one of the canisters crash-lands in George's habitat, and George is exposed to the pathogen..
# ['https://imdb-api.com/images/original/MV5BMTAyMzA2MTcwNDFeQTJeQWpwZ15BbWU4MDQxOTkyMDUz._V1_Ratio1.3800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTE0MDg3Njc5MzleQTJeQWpwZ15BbWU4MDA5ODkyMDUz._V1_Ratio2.3800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BNDUxMmQxOGMtZDE1MS00ZDAxLTgwMjQtYzg0ZjU1YThmNzY0XkEyXkFqcGdeQXVyODYwMzA2ODY@._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BOTA2ZDU1ZWEtYjM4Zi00NDAxLWFiMzMtNTBiN2RlMjY2ZWI2XkEyXkFqcGdeQXVyODYwMzA2ODY@._V1_Ratio1.5000_AL_.jpg']
# Watchmen
# No. 92  match
# It's 1985 in an alternate reality. The Watchmen - comprised of the Comedian, Dr. Manhattan, Nite Owl II, Ozymandias, Rorschach and Silk Spectre II - are a disparate band of masked superheroes, modeled after the Minutemen, who were masked superheroes of a generation earlier, most of who are dead or afflicted by the ravages of life. The Comedian belongs to both groups. Despite the activities of the Watchmen leading to the west winning the Vietnam War which in turn has kept Richard Nixon in the White House, Nixon has now outlawed masks, resulting in the Watchmen disbanding and going into retirement, most hiding their Watchmen past under their human identities. However, the Comedian, in his human persona of Eddie Blake, and Dr. Manhattan - former physicist Jon Osterman who obtained his superhero powers through a scientific accident which almost killed him - now work for the government. Dr. Manhattan's powers in particular have kept a watch over nuclear proliferation, as he is able to stop any nuclear attack. Regardless, the Cold War is at its height with recent Soviet posturing regarding nuclear bomb buildup. In her human persona of Laurie Jupiter, Silk Spectre II is Dr. Manhattan's assistant and lover, as much as they can be in Dr. Manhattan's now non-human state. Meanwhile, Ozymandias has come out to the world as wealthy genius Adrian Veidt, capitalizing on his Ozymandias identity to better the world, and Rorschach continues to work as a vigilante, although one wanted by the law despite he the reason that many criminals are behind bars. When Blake is murdered, Rorschach, as the only one still on the streets, believes the murderer is out to kill all the Watchmen, despite any number of people wanting to kill the Comedian for being a misogynist. Evidence points to it perhaps having something to do with an imminent attempt of nuclear annihilation. Rorschach has to convince his colleagues, who he has not seen since their superhero days, of the validity of his theory for them to come out of retirement, which is no easy task. If they do, which will require them to overcome external forces which seem to be conspiring against them, they will have to discover both who killed the Comedian and why before they befall the same fate as him and/or before the mastermind is able to exact his larger grand plan.
# ['https://imdb-api.com/images/original/MV5BYjA4OGNlMDEtMGUwMi00MzM5LTk0NzctMTA0ZTc0NDNiZmI3XkEyXkFqcGdeQXVyMDM2NDM2MQ@@._V1_Ratio1.4800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BYTYwOTgxZTgtNTkzYi00NmNhLThmMDgtZjcyYjdkYmE1ZGJhXkEyXkFqcGdeQXVyMDM2NDM2MQ@@._V1_Ratio1.6000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjI5NzU3OTUyMF5BMl5BanBnXkFtZTgwOTM2OTA4NDM@._V1_Ratio1.4800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTk0MzY3MjExNV5BMl5BanBnXkFtZTcwNjU3MzIzMg@@._V1_Ratio1.4800_AL_.jpg']
# Inuyashiki
# No. 93  match
# Inuyashiki Ichirou is down on his luck. While only 58 years old, his geriatric looks often have him written off as a pathetic old man by the world around him and he's constantly ignored and disrespected by his family despite all that he's done to support them. On top of everything else, his doctor has revealed that he has cancer and it appears that he has little time left in this world. But just when it seems things couldn't get any worse, a blinding light in the night sky strikes the earth where Ichirou stands. He later wakes up to find himself unscathed, but he soon starts to notice that there's something... different about himself. However, it turns out that these strange, new changes are just what Ichirou needs to take a new lease on life and now it seems like there's nothing to stop him from being a hero worthy of the respect that he never had before... unless, that is, there was someone else out there with these same changes...
# ['https://imdb-api.com/images/original/MV5BNmI1YzZlYzItYjViYy00NjA2LThiMDAtNTdmMTBhZmUwOGIwXkEyXkFqcGdeQXVyMTA4NjE0NjEy._V1_Ratio1.0000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMzYzNmRmNzAtZjNmOS00NDg0LTgxYzItZGY0YThkMGIyMTc3XkEyXkFqcGdeQXVyNDQxNjcxNQ@@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BYTEzOWViZWYtZWNiMC00NGM1LTg2NTQtNWQ2YzQ1NmUzZTc4XkEyXkFqcGdeQXVyNDQxNjcxNQ@@._V1_Ratio1.5200_AL_.jpg', 'https://imdb-api.com/images/original/MV5BYTdmOWQwNWItMTcxNi00MmEyLWE2NGMtZmQyY2JjNmNhNjVhXkEyXkFqcGdeQXVyNDQxNjcxNQ@@._V1_Ratio1.5000_AL_.jpg']
# Avengers: Endgame
# No. 94  match
# After the devastating events of Avengers: Infinity War (2018), the universe is in ruins due to the efforts of the Mad Titan, Thanos. With the help of remaining allies, the Avengers must assemble once more in order to undo Thanos's actions and undo the chaos to the universe, no matter what consequences may be in store, and no matter who they face...
# ['https://imdb-api.com/images/original/MV5BMTlmOGE2ZWMtODA4MS00M2Q0LTg5MDktYzY2MmYzOWRhZWVlXkEyXkFqcGdeQXVyODkzNTgxMDg@._V1_Ratio1.9000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BNDQ1YjBkNGEtYzUxZi00NzUyLTgwZGUtYmFhZTkzYTJkOTk0XkEyXkFqcGdeQXVyNjg2NjQwMDQ@._V1_Ratio1.9000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BZmRmNjhmOGItNWMzNi00NTMyLTgzZTktY2UxMzQ4YjhhN2YxXkEyXkFqcGdeQXVyNjg2NjQwMDQ@._V1_Ratio1.9000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BZGFmYWU1OGUtYmUxNS00N2E4LTkxYmMtZGYxM2NmYzhjZjJkXkEyXkFqcGdeQXVyNjg2NjQwMDQ@._V1_Ratio1.9000_AL_.jpg']
# Black Panther
# No. 95  match
# After the events of Captain America: Civil War, Prince T'Challa returns home to the reclusive, technologically advanced African nation of Wakanda to serve as his country's new king. However, T'Challa soon finds that he is challenged for the throne from factions within his own country. When two foes conspire to destroy Wakanda, the hero known as Black Panther must team up with C.I.A. agent Everett K. Ross and members of the Dora Milaje, Wakandan special forces, to prevent Wakanda from being dragged into a world war.
# ['https://imdb-api.com/images/original/MV5BMTA5MDIxMzA5MjNeQTJeQWpwZ15BbWU4MDUzNzAzOTQz._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjE5NzU5MzcwMF5BMl5BanBnXkFtZTgwNjM3MDM5NDM@._V1_Ratio1.9000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTUyMDQzODM4MV5BMl5BanBnXkFtZTgwNzM3MDM5NDM@._V1_Ratio1.9000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjIzNzYwNjkyOF5BMl5BanBnXkFtZTgwODM3MDM5NDM@._V1_Ratio1.9000_AL_.jpg']
# Jurassic World: Fallen Kingdom
# No. 96  match
# Three years after the Jurassic World theme park was closed down, Owen and Claire return to Isla Nublar to save the dinosaurs when they learn that a once dormant volcano on the island is active and is threatening to extinguish all life there. Along the way, Owen sets out to find Blue, his lead raptor, and discovers a conspiracy that could disrupt the natural order of the entire planet. Life has found a way, again.
# ['https://imdb-api.com/images/original/MV5BNTM4ODQxMTA3MV5BMl5BanBnXkFtZTgwNjkwNDMzNTM@._V1_Ratio2.3800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMzc3MTgzODk0MV5BMl5BanBnXkFtZTgwNzkwNDMzNTM@._V1_Ratio2.3800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjA3Mzk4ODYxOV5BMl5BanBnXkFtZTgwODkwNDMzNTM@._V1_Ratio1.9800_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjQwNDY1Nzk5M15BMl5BanBnXkFtZTgwOTkwNDMzNTM@._V1_Ratio2.0600_AL_.jpg']
# Avengers: Infinity War
# No. 97  match
# As the Avengers and their allies have continued to protect the world from threats too large for any one hero to handle, a new danger has emerged from the cosmic shadows: Thanos. A despot of intergalactic infamy, his goal is to collect all six Infinity Stones, artifacts of unimaginable power, and use them to inflict his twisted will on all of reality. Everything the Avengers have fought for has led up to this moment, the fate of Earth and existence has never been more uncertain.
# ['https://imdb-api.com/images/original/MV5BMjA0MTg0MjUwMF5BMl5BanBnXkFtZTgwMjc4MjkzNTM@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BNjI4NzM2MTM1M15BMl5BanBnXkFtZTgwMzc4MjkzNTM@._V1_Ratio1.9000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjQwNTgxMTEwNl5BMl5BanBnXkFtZTgwNDc4MjkzNTM@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTk0OTc5Njg5M15BMl5BanBnXkFtZTgwNTc4MjkzNTM@._V1_Ratio1.9000_AL_.jpg']
# None
# No. 98  dont`t match, recorded
# X-Men: Days of Future Past
# No. 99  match
# In the future, the mutants and the humans who help them are slaughtered by powerful robots named Sentinels. Professor Xavier, Wolverine, Magneto, Storm, Kitty Pryde, and her friends meet at a monastery in China and Xavier explains that the invincible Sentinels were created using the DNA of Mystique that was captured in 1973 when she tried to assassinate their creator Dr. Bolivar Trask. Xavier tells that their only chance is return to 1973 using Pryde's ability to join Charles Xavier and Erik Lehnsherr to convince Mystique to give up her intention. However, only Wolverine can withstand the damages of the time travel. Will he succeed in stopping Mystique and the Sentinel Program, and save the mutants and their human friends from annihilation?
# ['https://imdb-api.com/images/original/MV5BMTgwMDkwMDI5N15BMl5BanBnXkFtZTgwNzQ2NzQzMjI@._V1_Ratio1.5000_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTkyMjQxNjkwOV5BMl5BanBnXkFtZTgwMjA2NDI0MTE@._V1_Ratio1.4200_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMTQyNjAxMDU0OF5BMl5BanBnXkFtZTgwMzA2NDI0MTE@._V1_Ratio1.4200_AL_.jpg', 'https://imdb-api.com/images/original/MV5BMjE0OTE0NDQxOF5BMl5BanBnXkFtZTgwNDA2NDI0MTE@._V1_Ratio1.4200_AL_.jpg']
# None
# No. 100  dont`t match, recorded
# None
# No. 101  dont`t match, recorded
# None
# No. 102  dont`t match, recorded
# None
# No. 103  dont`t match, recorded
# None
# No. 104  dont`t match, recorded
# None
# No. 105  dont`t match, recorded
# None
# No. 106  dont`t match, recorded
# None
# No. 107  dont`t match, recorded
# None
# No. 108  dont`t match, recorded
# None
# No. 109  dont`t match, recorded
# None
# No. 110  dont`t match, recorded
# None
# No. 111  dont`t match, recorded
# None
# No. 112  dont`t match, recorded
# None
# No. 113  dont`t match, recorded
# None
# No. 114  dont`t match, recorded
# None
# No. 115  dont`t match, recorded
# None
# No. 116  dont`t match, recorded
# None
# No. 117  dont`t match, recorded
# None
# No. 118  dont`t match, recorded
# None
# No. 119  dont`t match, recorded
# None
# No. 120  dont`t match, recorded
# None
# No. 121  dont`t match, recorded
# None
# No. 122  dont`t match, recorded
# None
# No. 123  dont`t match, recorded
# None
# No. 124  dont`t match, recorded
# None
# No. 125  dont`t match, recorded
# None
# No. 126  dont`t match, recorded
# None
# No. 127  dont`t match, recorded
# None
# No. 128  dont`t match, recorded
# None
# No. 129  dont`t match, recorded
# None
# No. 130  dont`t match, recorded
# None
# No. 131  dont`t match, recorded
# None
# No. 132  dont`t match, recorded
# None
# No. 133  dont`t match, recorded
# None
# No. 134  dont`t match, recorded
# None
# No. 135  dont`t match, recorded
# None
# No. 136  dont`t match, recorded
# None
# No. 137  dont`t match, recorded
# None
# No. 138  dont`t match, recorded
# None
# No. 139  dont`t match, recorded
# None
# No. 140  dont`t match, recorded
# None
# No. 141  dont`t match, recorded
# None
# No. 142  dont`t match, recorded
# None
# No. 143  dont`t match, recorded
# None
# No. 144  dont`t match, recorded
# [98, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144]

# %%
'''
print(imDb_score,len(imDb_score))
print(mct_score,len(mct_score))
print(rT_score,len(rT_score))
'''
print('title',len(i_title),'id',len(i_id),'plot:',len(plot),'images:',len(images))
print(bp)
print(flag)
# Out:
# title 46 id 46 plot: 145 images: 145
# [98, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144]
# 145

# %%
#print('title',len(r_title),'id',len(r_id),'IMDB:',len(imDb_score),'MTC:',len(mct_score),'RottenTomatoes:',len(rT_score))
dic={'i_title':i_title,'i_id':i_id,'plot':plot,'images':images}
df2 = pd.DataFrame(dic)
df2.to_csv('p&i.csv',mode='w',index=False)
df2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-78c51b4e0316> in <module>
#       1 #print('title',len(r_title),'id',len(r_id),'IMDB:',len(imDb_score),'MTC:',len(mct_score),'RottenTomatoes:',len(rT_score))
#       2 dic={'i_title':i_title,'i_id':i_id,'plot':plot,'images':images}
# ----> 3 df2 = pd.DataFrame(dic)
#       4 df2.to_csv('rating.csv',mode='w',index=False)
#       5 df2
#
# D:\python\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# D:\python\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# D:\python\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      76         # figure out the index, if necessary
#      77         if index is None:
# ---> 78             index = extract_index(arrays)
#      79         else:
#      80             index = ensure_index(index)
#
# D:\python\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     395             lengths = list(set(raw_lengths))
#     396             if len(lengths) > 1:
# --> 397                 raise ValueError("arrays must all be same length")
#     398
#     399             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
import requests

api_search = "https://imdb-api.com/en/API/Title/k_qn8i9tcr/"

#print(result[0],type(result[0]))
#print(str(result[0]).strip(''))
#print(df.iloc[0,0],type(df.iloc[0,0]))

r=requests.get(api_search+df.loc[0,'id']+'/Images')

print(r.text)
# Out:
# {"id":"tt2660888","title":"Star Trek Beyond","originalTitle":"","fullTitle":"Star Trek Beyond (2016)","type":"Movie","year":"2016","image":"https://imdb-api.com/images/original/MV5BODgzMTZmMGMtNTM4Ni00ZjIxLWIyYmUtZjcxMDEwMjkxMzQyXkEyXkFqcGdeQXVyMjMwNDgzNjc@._V1_Ratio0.6762_AL_.jpg","releaseDate":"2016-07-21","runtimeMins":"122","runtimeStr":"2h 2min","plot":"After stopping off at Starbase Yorktown, a remote outpost on the fringes of Federation space, the USS Enterprise, halfway into their five-year mission, is destroyed by an unstoppable wave of unknown aliens. With the crew stranded on an unknown planet and with no apparent means of rescue, they find themselves fighting against a ruthless enemy with a well-earned hatred of the Federation and everything it stands for. Only a rebellious alien warrior can help them reunite and leave the planet to stop this deadly menace from beginning a possible galactic war.","plotLocal":"","plotLocalIsRtl":false,"awards":"Nominated for 1 Oscar3 wins & 29 nominations total","directors":"Justin Lin","directorList":[{"id":"nm0510912","name":"Justin Lin"}],"writers":"Simon Pegg, Doug Jung, Gene Roddenberry","writerList":[{"id":"nm0670408","name":"Simon Pegg"},{"id":"nm1136647","name":"Doug Jung"},{"id":"nm0734472","name":"Gene Roddenberry"}],"stars":"Chris Pine, Zachary Quinto, Karl Urban","starList":[{"id":"nm1517976","name":"Chris Pine"},{"id":"nm0704270","name":"Zachary Quinto"},{"id":"nm0881631","name":"Karl Urban"}],"actorList":[{"id":"nm1517976","image":"https://imdb-api.com/images/original/MV5BMTM4OTQ4NTU3NV5BMl5BanBnXkFtZTcwNjEwNDU0OQ@@._V1_Ratio1.0000_AL_.jpg","name":"Chris Pine","asCharacter":"Captain James T. Kirkas Captain James T. Kirk"},{"id":"nm0704270","image":"https://imdb-api.com/images/original/MV5BMjQ4NDQ2MmYtODY3OS00MjE1LTk4ZjktNTE2OGQ1NmZhNzgyXkEyXkFqcGdeQXVyMjQwMDg0Ng@@._V1_Ratio1.0000_AL_.jpg","name":"Zachary Quinto","asCharacter":"Commander Spockas Commander Spock"},{"id":"nm0881631","image":"https://imdb-api.com/images/original/MV5BMTU2Njg3MDgyN15BMl5BanBnXkFtZTcwNjgyNTA4Mg@@._V1_Ratio1.0000_AL_.jpg","name":"Karl Urban","asCharacter":"Doctor 'Bones' McCoyas Doctor 'Bones' McCoy"},{"id":"nm0757855","image":"https://imdb-api.com/images/original/MV5BMTM2MjIwOTc0Nl5BMl5BanBnXkFtZTcwNzQ5ODM1Mw@@._V1_Ratio1.0000_AL_.jpg","name":"Zoe Saldana","asCharacter":"Lieutenant Uhuraas Lieutenant Uhura"},{"id":"nm0670408","image":"https://imdb-api.com/images/original/MV5BNzMwODE1NjA3OV5BMl5BanBnXkFtZTgwNTY5MzM2OTE@._V1_Ratio1.0000_AL_.jpg","name":"Simon Pegg","asCharacter":"Montgomery 'Scotty' Scottas Montgomery 'Scotty' Scott"},{"id":"nm0158626","image":"https://imdb-api.com/images/original/MV5BMjM4Nzk2NjUxNF5BMl5BanBnXkFtZTgwMzY3NDI2MTI@._V1_Ratio1.0000_AL_.jpg","name":"John Cho","asCharacter":"Suluas Sulu"},{"id":"nm0947338","image":"https://imdb-api.com/images/original/MV5BMzQ5ODE1OTE5NF5BMl5BanBnXkFtZTcwMDQwMjExNw@@._V1_Ratio1.0000_AL_.jpg","name":"Anton Yelchin","asCharacter":"Chekovas Chekov"},{"id":"nm0252961","image":"https://imdb-api.com/images/original/MV5BNzEzMTI2NjEyNF5BMl5BanBnXkFtZTcwNTA0OTE4OA@@._V1_Ratio1.0000_AL_.jpg","name":"Idris Elba","asCharacter":"Krallas Krall"},{"id":"nm1154749","image":"https://imdb-api.com/images/original/MV5BMjU0OTQ5NjQ5NF5BMl5BanBnXkFtZTgwNTk2ODQzNDE@._V1_Ratio1.0000_AL_.jpg","name":"Sofia Boutella","asCharacter":"Jaylahas Jaylah"},{"id":"nm3029144","image":"https://imdb-api.com/images/original/MV5BNDQzMjk3YjEtZjU5Ny00M2M5LTg0N2UtZGVjZDJkNWIxOGI0XkEyXkFqcGdeQXVyMjQwMDg0Ng@@._V1_Ratio1.5000_AL_.jpg","name":"Joe Taslim","asCharacter":"Manasas Manas"},{"id":"nm3575723","image":"https://imdb-api.com/images/original/MV5BMDdhYmZmOTMtOTQxOC00ODVmLTg5YjgtNTk3ZWJhMjVlMTBkXkEyXkFqcGdeQXVyMjQwMDg0Ng@@._V1_Ratio1.0000_AL_.jpg","name":"Lydia Wilson","asCharacter":"Kalaraas Kalara"},{"id":"nm0746989","image":"https://imdb-api.com/images/original/MV5BMTczNjk4OTY5MV5BMl5BanBnXkFtZTcwOTcxMjgyMQ@@._V1_Ratio1.0000_AL_.jpg","name":"Deep Roy","asCharacter":"Keense ...

# %%
content = r.json()

#content = content["results"]

print(content)
print(type(content))
# Out:
# {'id': 'tt2660888', 'title': 'Star Trek Beyond', 'originalTitle': '', 'fullTitle': 'Star Trek Beyond (2016)', 'type': 'Movie', 'year': '2016', 'image': 'https://imdb-api.com/images/original/MV5BODgzMTZmMGMtNTM4Ni00ZjIxLWIyYmUtZjcxMDEwMjkxMzQyXkEyXkFqcGdeQXVyMjMwNDgzNjc@._V1_Ratio0.6762_AL_.jpg', 'releaseDate': '2016-07-21', 'runtimeMins': '122', 'runtimeStr': '2h 2min', 'plot': 'After stopping off at Starbase Yorktown, a remote outpost on the fringes of Federation space, the USS Enterprise, halfway into their five-year mission, is destroyed by an unstoppable wave of unknown aliens. With the crew stranded on an unknown planet and with no apparent means of rescue, they find themselves fighting against a ruthless enemy with a well-earned hatred of the Federation and everything it stands for. Only a rebellious alien warrior can help them reunite and leave the planet to stop this deadly menace from beginning a possible galactic war.', 'plotLocal': '', 'plotLocalIsRtl': False, 'awards': 'Nominated for 1 Oscar3 wins & 29 nominations total', 'directors': 'Justin Lin', 'directorList': [{'id': 'nm0510912', 'name': 'Justin Lin'}], 'writers': 'Simon Pegg, Doug Jung, Gene Roddenberry', 'writerList': [{'id': 'nm0670408', 'name': 'Simon Pegg'}, {'id': 'nm1136647', 'name': 'Doug Jung'}, {'id': 'nm0734472', 'name': 'Gene Roddenberry'}], 'stars': 'Chris Pine, Zachary Quinto, Karl Urban', 'starList': [{'id': 'nm1517976', 'name': 'Chris Pine'}, {'id': 'nm0704270', 'name': 'Zachary Quinto'}, {'id': 'nm0881631', 'name': 'Karl Urban'}], 'actorList': [{'id': 'nm1517976', 'image': 'https://imdb-api.com/images/original/MV5BMTM4OTQ4NTU3NV5BMl5BanBnXkFtZTcwNjEwNDU0OQ@@._V1_Ratio1.0000_AL_.jpg', 'name': 'Chris Pine', 'asCharacter': 'Captain James T. Kirkas Captain James T. Kirk'}, {'id': 'nm0704270', 'image': 'https://imdb-api.com/images/original/MV5BMjQ4NDQ2MmYtODY3OS00MjE1LTk4ZjktNTE2OGQ1NmZhNzgyXkEyXkFqcGdeQXVyMjQwMDg0Ng@@._V1_Ratio1.0000_AL_.jpg', 'name': 'Zachary Quinto', 'asCharacter': 'Commander Spockas Commander Spock'}, {'id': 'nm0881631', 'image': 'https://imdb-api.com/images/original/MV5BMTU2Njg3MDgyN15BMl5BanBnXkFtZTcwNjgyNTA4Mg@@._V1_Ratio1.0000_AL_.jpg', 'name': 'Karl Urban', 'asCharacter': "Doctor 'Bones' McCoyas Doctor 'Bones' McCoy"}, {'id': 'nm0757855', 'image': 'https://imdb-api.com/images/original/MV5BMTM2MjIwOTc0Nl5BMl5BanBnXkFtZTcwNzQ5ODM1Mw@@._V1_Ratio1.0000_AL_.jpg', 'name': 'Zoe Saldana', 'asCharacter': 'Lieutenant Uhuraas Lieutenant Uhura'}, {'id': 'nm0670408', 'image': 'https://imdb-api.com/images/original/MV5BNzMwODE1NjA3OV5BMl5BanBnXkFtZTgwNTY5MzM2OTE@._V1_Ratio1.0000_AL_.jpg', 'name': 'Simon Pegg', 'asCharacter': "Montgomery 'Scotty' Scottas Montgomery 'Scotty' Scott"}, {'id': 'nm0158626', 'image': 'https://imdb-api.com/images/original/MV5BMjM4Nzk2NjUxNF5BMl5BanBnXkFtZTgwMzY3NDI2MTI@._V1_Ratio1.0000_AL_.jpg', 'name': 'John Cho', 'asCharacter': 'Suluas Sulu'}, {'id': 'nm0947338', 'image': 'https://imdb-api.com/images/original/MV5BMzQ5ODE1OTE5NF5BMl5BanBnXkFtZTcwMDQwMjExNw@@._V1_Ratio1.0000_AL_.jpg', 'name': 'Anton Yelchin', 'asCharacter': 'Chekovas Chekov'}, {'id': 'nm0252961', 'image': 'https://imdb-api.com/images/original/MV5BNzEzMTI2NjEyNF5BMl5BanBnXkFtZTcwNTA0OTE4OA@@._V1_Ratio1.0000_AL_.jpg', 'name': 'Idris Elba', 'asCharacter': 'Krallas Krall'}, {'id': 'nm1154749', 'image': 'https://imdb-api.com/images/original/MV5BMjU0OTQ5NjQ5NF5BMl5BanBnXkFtZTgwNTk2ODQzNDE@._V1_Ratio1.0000_AL_.jpg', 'name': 'Sofia Boutella', 'asCharacter': 'Jaylahas Jaylah'}, {'id': 'nm3029144', 'image': 'https://imdb-api.com/images/original/MV5BNDQzMjk3YjEtZjU5Ny00M2M5LTg0N2UtZGVjZDJkNWIxOGI0XkEyXkFqcGdeQXVyMjQwMDg0Ng@@._V1_Ratio1.5000_AL_.jpg', 'name': 'Joe Taslim', 'asCharacter': 'Manasas Manas'}, {'id': 'nm3575723', 'image': 'https://imdb-api.com/images/original/MV5BMDdhYmZmOTMtOTQxOC00ODVmLTg5YjgtNTk3ZWJhMjVlMTBkXkEyXkFqcGdeQXVyMjQwMDg0Ng@@._V1_Ratio1.0000_AL_.jpg', 'name': 'Lydia Wilson', 'asCharacter': 'Kalaraas Kalara'}, {'id': 'nm0746989', 'im ...
# <class 'dict'>

# %%
#info = content[0]

print(content['title'])
print(content['plot'])
print(content.keys())

#print('IMDB:',content['imDb'],'MTC:',content['metacritic'],'RottenTomatoes:',content['rottenTomatoes'])
# Out:
# Star Trek Beyond
# After stopping off at Starbase Yorktown, a remote outpost on the fringes of Federation space, the USS Enterprise, halfway into their five-year mission, is destroyed by an unstoppable wave of unknown aliens. With the crew stranded on an unknown planet and with no apparent means of rescue, they find themselves fighting against a ruthless enemy with a well-earned hatred of the Federation and everything it stands for. Only a rebellious alien warrior can help them reunite and leave the planet to stop this deadly menace from beginning a possible galactic war.
# dict_keys(['id', 'title', 'originalTitle', 'fullTitle', 'type', 'year', 'image', 'releaseDate', 'runtimeMins', 'runtimeStr', 'plot', 'plotLocal', 'plotLocalIsRtl', 'awards', 'directors', 'directorList', 'writers', 'writerList', 'stars', 'starList', 'actorList', 'fullCast', 'genres', 'genreList', 'companies', 'companyList', 'countries', 'countryList', 'languages', 'languageList', 'contentRating', 'imDbRating', 'imDbRatingVotes', 'metacriticRating', 'ratings', 'wikipedia', 'posters', 'images', 'trailer', 'boxOffice', 'tagline', 'keywords', 'keywordList', 'similars', 'tvSeriesInfo', 'tvEpisodeInfo', 'errorMessage'])

# %%
#print(content['images']['items'])
imgL = content['images']['items']
for i in range(4):
    print (imgL[i]['image'])
# Out:
# https://imdb-api.com/images/original/MV5BMTU4MTY1NDExNF5BMl5BanBnXkFtZTgwMzE5NzA1MjI@._V1_Ratio1.7800_AL_.jpg
# https://imdb-api.com/images/original/MV5BODM4MzExNzc4OF5BMl5BanBnXkFtZTgwNTk1NDQ0OTE@._V1_Ratio1.5400_AL_.jpg
# https://imdb-api.com/images/original/MV5BMTUwNTI5OTY4MV5BMl5BanBnXkFtZTgwNjk1NDQ0OTE@._V1_Ratio1.5000_AL_.jpg
# https://imdb-api.com/images/original/MV5BMjI0MDEwMzQwNV5BMl5BanBnXkFtZTgwNzk1NDQ0OTE@._V1_Ratio1.5000_AL_.jpg

# %%
#print((info['description']))
print(df.loc[0,'title'])
#print(int(info['description'][1:5]))

if df.loc[0,'title'] == content['title']:
    print("match")
'''
try :
    #d=int(info['description'][1:-1])
    if df.loc[0,'title'] == content['title']:
        print("match")
except ValueError as v:
    print("Exception occurred.",v)
'''
# Out:
# Star Trek Beyond
# match
# '\ntry :\n    #d=int(info[\'description\'][1:-1])\n    if df.loc[0,\'title\'] == content[\'title\']:\n        print("match")\nexcept ValueError as v:\n    print("Exception occurred.",v)\n'
